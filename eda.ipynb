# %%
import pandas as pd
import numpy as np
import networkx as nx

# %%
data = np.genfromtxt('/content/sample_data/USA-road-d.COL.gr', usecols=(1,2,3))
np.savetxt('cleanedRoadCOL', data, fmt='%d')

# %%
G = nx.read_weighted_edgelist('cleanedRoadCOL', create_using=nx.DiGraph(), nodetype=int)

# %%
G.number_of_nodes()

# %%
G.number_of_edges()
